# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Full Sim results
fullsims = {'rcut':400, 'sthresh':0, 'data':
            {'s1.3mmp15mm':{'size':1.3, 'teflon':'no_teflon',
                           'name':'1.3 mm size, 15 mm pitch',
                           'coverage':0.7, 'sipm_eres':6.13},
           's1.3mmp7mm':{'size':1.3, 'teflon':'no_teflon',
                           'name':'1.3 mm size, 7 mm pitch',
                           'coverage':3.4, 'sipm_eres':3.56},
           's1.3mmp1.3mm':{'size':1.3, 'teflon':'no_teflon',
                           'name':'1.3 mm size, 1.3 mm pitch',
                           'coverage':98.4, 'sipm_eres':2.68},
           's3mmp15mm':{'size':3, 'teflon':'no_teflon',
                           'name':'3 mm size, 15 mm pitch',
                           'coverage':3.9, 'sipm_eres':3.35},
           's3mmp7mm':{'size':3, 'teflon':'no_teflon',
                           'name':'3 mm size, 7 mm pitch',
                           'coverage':18.1, 'sipm_eres':2.64},
           's3mmp3mm':{'size':3, 'teflon':'no_teflon',
                           'name':'3 mm size, 3 mm pitch',
                           'coverage':98.4, 'sipm_eres':2.438},
           's6mmp15mm':{'size':6, 'teflon':'no_teflon',
                           'name':'6 mm size, 15 mm pitch',
                           'coverage':15.7, 'sipm_eres':2.59},
           's6mmp6mm':{'size':6, 'teflon':'no_teflon',
                           'name':'6 mm size, 6 mm pitch',
                           'coverage':98.4, 'sipm_eres':2.47}}}

# %%
data_r400s3 = {'rcut':400, 'sthresh':3, 'data':{"s1.3mmp15mm": {"size": 1.3, "pitch": 15.0, "teflon": "no_teflon", "name": "1.3 mm size, 15.0 pitch, no_teflon", "num_sipms": 3308, "coverage": 0.735143509529796, "sipm_eres": 6.9639595011889766, "sipm_fwhm": 83.91060551466896, "sipm_mean": 1204.9266728266105, "sipm_eres_err": 0.0023321759207838634, "sipm_fwhm_err": 1.1911801712485832, "sipm_mean_err": 1.5059086188894077, "sipm_chi2": 1.5973018005981876}, "s1.3mmp7mm": {"size": 1.3, "pitch": 7, "teflon": "no_teflon", "name": "1.3 mm size, 7 pitch, no_teflon", "num_sipms": 15268, "coverage": 3.3930384230655766, "sipm_eres": 4.071274647394134, "sipm_fwhm": 224.97976793195818, "sipm_mean": 5526.027777957919, "sipm_eres_err": 0.0013156771352399478, "sipm_fwhm_err": 3.089735138470778, "sipm_mean_err": 3.901957597002731, "sipm_chi2": 0.7395326650824574}, "s3mmp15mm": {"size": 3, "pitch": 15, "teflon": "no_teflon", "name": "3 mm size, 15 pitch, no_teflon", "num_sipms": 3308, "coverage": 3.9149654353657777, "sipm_eres": 4.055585635167217, "sipm_fwhm": 397.6716555517863, "sipm_mean": 9805.529739119656, "sipm_eres_err": 0.0013329212325727511, "sipm_fwhm_err": 5.554627516164644, "sipm_mean_err": 6.914528351006347, "sipm_chi2": 0.7261926566171383}, "s3mmp7mm": {"size": 3, "pitch": 7, "teflon": "no_teflon", "name": "3 mm size, 7 pitch, no_teflon", "num_sipms": 15268, "coverage": 18.06943538910662, "sipm_eres": 3.333889110178146, "sipm_fwhm": 1504.8199021764583, "sipm_mean": 45137.07122358513, "sipm_eres_err": 0.0010636834289204826, "sipm_fwhm_err": 20.41210915229735, "sipm_mean_err": 25.959771411130408, "sipm_chi2": 0.9532849693299279}, "s3mmp15mm_teflon": {"size": 3, "pitch": 15, "teflon": "teflon", "name": "3 mm size, 15 pitch, teflon", "num_sipms": 3308, "coverage":
mm size, 15 pitch, teflon", "num_sipms": 3308, "coverage": 3.9149654353657777, "sipm_eres": 3.772857012925679, "sipm_fwhm": 368.28240817070133, "sipm_mean": 9761.366701917894, "sipm_eres_err": 0.0004415683836282124, "sipm_fwhm_err": 1.831622342647611, "sipm_mean_err": 2.563882172268483, "sipm_chi2": 1.6556850346190441}, "s3mmp7mm_teflon": {"size": 3, "pitch": 7, "teflon": "teflon", "name": "3 mm size, 7 pitch, teflon", "num_sipms": 15268, "coverage": 18.06943538910662, "sipm_eres": 2.9159504513811725, "sipm_fwhm": 1279.9095669747253, "sipm_mean": 43893.392165442376, "sipm_eres_err": 0.00033667829711953734, "sipm_fwhm_err": 6.283273179227103, "sipm_mean_err": 8.782924469615278, "sipm_chi2": 0.7420079746125386}, "s6mmp15mm_teflon": {"size": 6, "pitch": 15, "teflon": "teflon", "name": "6 mm size, 15 pitch, teflon", "num_sipms": 3308, "coverage": 15.65986174146311, "sipm_eres": 8.846688506374317, "sipm_fwhm": 5329.215936925745, "sipm_mean": 60239.669714672076, "sipm_eres_err": 0.0010183293584701048, "sipm_fwhm_err": 25.861428840010017, "sipm_mean_err": 40.11212175284567, "sipm_chi2": 23.43549904679088}}}
all_data = [data_r400s0, data_r400s1, data_r400s3, data_r400s5]

# %%
# Plot the eres for each configuration
this_data = data_r400s3
eres = {1.3:{'C':[],'eres':[], 'mean':[], 'fwhm':[]}, 3:{'C':[],'eres':[], 'mean':[], 'fwhm':[]}, 6:{'C':[],'eres':[], 'mean':[], 'fwhm':[]}} 
eres_teflon = {1.3:{'C':[],'eres':[], 'mean':[], 'fwhm':[]}, 3:{'C':[],'eres':[], 'mean':[], 'fwhm':[]}, 6:{'C':[],'eres':[], 'mean':[], 'fwhm':[]}} 
for config in this_data['data']:
    size = this_data['data'][config]['size']
    if this_data['data'][config]['teflon']=='no_teflon':
        eres[size]['C'].append(this_data['data'][config]['coverage'])
        eres[size]['eres'].append(this_data['data'][config]['sipm_eres'])
        eres[size]['mean'].append(this_data['data'][config]['sipm_mean'])
        eres[size]['fwhm'].append(this_data['data'][config]['sipm_fwhm'])
    else:
        eres_teflon[size]['C'].append(this_data['data'][config]['coverage'])
        eres_teflon[size]['eres'].append(this_data['data'][config]['sipm_eres'])
        eres_teflon[size]['mean'].append(this_data['data'][config]['sipm_mean'])
        eres_teflon[size]['fwhm'].append(this_data['data'][config]['sipm_fwhm'])

# %%
colors = ['r','b','g']
i = 0
for size in eres:
    plt.plot(eres_teflon[size]['C'], eres_teflon[size]['eres'], '+', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
    plt.plot(eres[size]['C'], eres[size]['eres'], 'o', linestyle='--', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.legend()
    i += 1
plt.title('Eres (FWHM) at 41.5 keV')
plt.show()

# %%
cuts_string = f"R < {this_data['rcut']}, SiPM > {this_data['sthresh']} pes"
i = 0
for size in eres:
    plt.plot(eres[size]['C'], eres[size]['eres'], 'o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('Eres (FWHM) at 41.5 keV')
    plt.legend()
    i += 1
plt.title('Kr83m Events, no teflon, '+cuts_string)
plt.show()

i = 0
for size in eres:
    plt.plot(eres_teflon[size]['C'], eres_teflon[size]['eres'], 'o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
    plt.xlabel('Coverage')
    plt.ylabel('Eres (FWHM) at 41.5 keV')
    plt.legend()
    i += 1
plt.title('Kr83m Events, teflon, '+cuts_string)
plt.show()

# %%
i = 0
for size in eres:
    plt.plot(eres[size]['C'], eres[size]['mean'], 'o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('Mean Charge [pes]')
    plt.ylim(-10000,360000)
    plt.legend()
    i += 1
plt.title('Kr83m Events, no teflon, '+cuts_string)
plt.show()

i = 0
for size in eres:
    plt.plot(eres_teflon[size]['C'], eres_teflon[size]['mean'], 'o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
    plt.xlabel('Coverage')
    plt.ylabel('Mean Charge [pes]')
    plt.legend()
    i += 1
plt.title('Kr83m Events, teflon, '+cuts_string)
plt.show()

# %%
i = 0
for size in eres:
    plt.plot(eres[size]['C'], eres[size]['fwhm'], 'o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('FWHM')
    plt.ylim(-500, 50000)
    plt.legend()
    i += 1
plt.title('Kr83m Events, no teflon, '+cuts_string)
plt.show()

i = 0
for size in eres:
    plt.plot(eres_teflon[size]['C'], eres_teflon[size]['fwhm'], 'o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
    plt.xlabel('Coverage')
    plt.ylabel('FWHM')
    plt.legend()
    i += 1
plt.title('Kr83m Events, teflon, '+cuts_string)
plt.show()

# %%
all_data
# Out:
# [{'rcut': 400,
#   'sthresh': 0,
#   'data': {'s1.3mmp15mm': {'size': 1.3,
#     'pitch': 15.0,
#     'teflon': 'no_teflon',
#     'name': '1.3 mm size, 15.0 pitch, no_teflon',
#     'num_sipms': 3308,
#     'coverage': 0.735143509529796,
#     'sipm_eres': 16.973998265967374,
#     'sipm_fwhm': 300.1996515548038,
#     'sipm_mean': 1768.5853789481046,
#     'sipm_eres_err': 0.0012660854490528855,
#     'sipm_fwhm_err': 0.9235155651478465,
#     'sipm_mean_err': 1.3820002662979483,
#     'sipm_chi2': 6.57412832054151},
#    's1.3mmp7mm': {'size': 1.3,
#     'pitch': 7,
#     'teflon': 'no_teflon',
#     'name': '1.3 mm size, 7 pitch, no_teflon',
#     'num_sipms': 15268,
#     'coverage': 3.3930384230655766,
#     'sipm_eres': 14.020001482830661,
#     'sipm_fwhm': 1139.347027836549,
#     'sipm_mean': 8126.582791248841,
#     'sipm_eres_err': 0.00095112658314622,
#     'sipm_fwhm_err': 3.199025150931619,
#     'sipm_mean_err': 5.453033952810949,
# ...

# %%
means = {} # {configs:{means:[means by thresh], thresh:[]}}
for mc in all_data:
    for config in mc['data']:
        try:
            means[config]
        except:
            means[config] = {'means':[], 'sthreshs':[]}
        means[config]['means'].append(mc['data'][config]['sipm_mean'])
        means[config]['sthreshs'].append(mc['sthresh'])

# %%
for config in means:
    if config == 's1.3mmp1.3mm' or config == 's3mmp3mm' or config == 's6mmp6mm':
        plt.plot(means[config]['sthreshs'], means[config]['means'], '-o', label=config)
plt.xlabel('SiPM Threshold [pes]')
plt.ylabel('Mean Total Charge [pes]')
plt.legend()
plt.show()

# %%
# New data varying thresh for sipm size
data_s1 = {"s1.3mmp15mm": {"size": 1.3, "pitch": 15.0, "teflon": "no_teflon", "name": "1.3 mm size, 15.0 pitch, no_teflon", "num_sipms": 3308, "coverage": 0.735143509529796, "rcut": 400, "sthresh": 1, "sipm_eres": 7.75678286195819, "sipm_fwhm": 108.33498679559918, "sipm_mean": 1396.6484394826819, "sipm_eres_err": 0.0006737806566470232, "sipm_fwhm_err": 0.3980881832116744, "sipm_mean_err": 0.5587183309248872, "sipm_chi2": 2.239070676282783}, "s1.3mmp7mm": {"size": 1.3, "pitch": 7, "teflon": "no_teflon", "name": "1.3 mm size, 7 pitch, no_teflon",
mm size, 15 pitch, teflon", "num_sipms": 3308, "coverage": 0.735143509529796, "rcut": 400, "sthresh": 2, "sipm_eres": 7.687958433705361, "sipm_fwhm": 100.8611325866778, "sipm_mean": 1311.9364972693513, "sipm_eres_err": 0.0007192731010528189, "sipm_fwhm_err": 0.399483535619376, "sipm_mean_err": 0.5291082815288535, "sipm_chi2": 1.6121064316844036}, "s1.3mmp7mm_teflon": {"size": 1.3, "pitch": 7, "teflon": "teflon", "name": "1.3 mm size, 7 pitch, teflon", "num_sipms": 15268, "coverage": 3.3930384230655766, "rcut": 400, "sthresh": 2, "sipm_eres": 4.237141492825324, "sipm_fwhm": 251.54112526767642, "sipm_mean": 5936.57600751843, "sipm_eres_err": 0.0003723602158041922, "sipm_fwhm_err": 0.939024257399973, "sipm_mean_err": 1.3075906249980578, "sipm_chi2": 0.18311306161842217}, "s3mmp15mm_teflon": {"size": 3, "pitch": 15, "teflon": "teflon", "name": "3 mm size, 15 pitch, teflon", "num_sipms": 3308, "coverage": 3.9149654353657777, "rcut": 400, "sthresh": 10, "sipm_eres": 3.664392304682831, "sipm_fwhm": 329.35373644780714, "sipm_mean": 8987.94968068557, "sipm_eres_err": 0.00035174996258833564, "sipm_fwhm_err": 1.3437932403643906, "sipm_mean_err": 1.750773914385455, "sipm_chi2": 1.2085312365535557}, "s3mmp7mm_teflon": {"size": 3, "pitch": 7, "teflon": "teflon", "name": "3 mm size, 7 pitch, teflon", "num_sipms": 15268, "coverage": 18.06943538910662, "rcut": 400, "sthresh": 10, "sipm_eres": 2.8026570623058435, "sipm_fwhm": 1151.1133318121629, "sipm_mean": 41072.214909700786, "sipm_eres_err": 0.00024553592017745573, "sipm_fwhm_err": 4.28805932271618, "sipm_mean_err": 6.007402542750733, "sipm_chi2": 0.10413823729903883}, "s6mmp15mm_teflon": {"size": 6, "pitch": 15, "teflon": "teflon", "name": "6 mm size, 15 pitch, teflon", "num_sipms": 3308, "coverage": 15.65986174146311, "rcut": 400, "sthresh": 42, "sipm_eres": 2.6908890636053377, "sipm_fwhm": 1088.8077276630456, "sipm_mean": 40462.75048605039, "sipm_eres_err": 0.0002453673463291935, "sipm_fwhm_err": 4.221930305090157, "sipm_mean_err": 5.767664300352522, "sipm_chi2": 0.8340779870048507}}

# %%
for config in data_s2:
    print(data_s2[config]['sthresh'])
# Out:
# 2
# 2
# 2
# 10
# 10
# 10
# 42
# 42
# 2
# 2
# 10
# 10
# 42

# %%
eres[3]['mean']
# Out:
# [9805.529739119656, 45137.07122358513, 232433.99127178942]

# %%
import numpy as np
8840 / np.sqrt(10000)
# Out:
# 88.4

# %%
# Plot the eres for each configuration
this_data = data_s2
eres = {1.3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
        3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
        6:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}} 
eres_teflon = {1.3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
               3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
               6:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}} 
fullsim_eres = {1.3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
               3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
               6:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}} 
for config in this_data:
    size = this_data[config]['size']
    if this_data[config]['teflon']=='no_teflon':
        eres[size]['C'].append(this_data[config]['coverage'])
        eres[size]['eres'].append(this_data[config]['sipm_eres'])
        eres[size]['mean'].append(this_data[config]['sipm_mean'])
        eres[size]['fwhm'].append(this_data[config]['sipm_fwhm'])
        eres[size]['eres_err'].append(this_data[config]['sipm_eres_err'])
        eres[size]['mean_err'].append(this_data[config]['sipm_mean_err'])
        eres[size]['fwhm_err'].append(this_data[config]['sipm_fwhm_err'])
        fullsim_eres[size]['C'].append(fullsims['data'][config]['coverage'])
        fullsim_eres[size]['eres'].append(fullsims['data'][config]['sipm_eres'])
    else:
        eres_teflon[size]['C'].append(this_data[config]['coverage'])
        eres_teflon[size]['eres'].append(this_data[config]['sipm_eres'])
        eres_teflon[size]['mean'].append(this_data[config]['sipm_mean'])
        eres_teflon[size]['fwhm'].append(this_data[config]['sipm_fwhm'])
        eres_teflon[size]['eres_err'].append(this_data[config]['sipm_eres_err'])
        eres_teflon[size]['mean_err'].append(this_data[config]['sipm_mean_err'])
        eres_teflon[size]['fwhm_err'].append(this_data[config]['sipm_fwhm_err'])
        
i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['eres'], yerr=eres[size]['eres_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('Eres (FWHM) % at 41.5 keV')
    plt.legend()
    i += 1
plt.title('Kr83m Events, no teflon')
plt.show()

i = 0
for size in eres:
    plt.errorbar(eres_teflon[size]['C'], eres_teflon[size]['eres'], yerr=eres_teflon[size]['eres_err'], 
             marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
    plt.xlabel('Coverage')
    plt.ylabel('Eres (FWHM) % at 41.5 keV')
    plt.legend()
    i += 1
plt.title('Kr83m Events, teflon')
plt.show() 

i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['mean'], eres[size]['mean_err'],
             marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('Mean Charge [pes]')
    plt.ylim(-10000,360000)
    plt.legend()
    i += 1
plt.title('Kr83m Events, no teflon')
plt.show()

i = 0
for size in eres:
    plt.errorbar(eres_teflon[size]['C'], eres_teflon[size]['mean'], eres_teflon[size]['mean_err'],
             marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
    plt.xlabel('Coverage')
    plt.ylabel('Mean Charge [pes]')
    plt.legend()
    i += 1
plt.title('Kr83m Events, teflon')
plt.show() 

i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['fwhm'], eres[size]['fwhm_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('FWHM')
    plt.ylim(-500, 50000)
    plt.legend()
    i += 1
plt.title('Kr83m Events, no teflon')
plt.show()

i = 0
for size in eres:
    plt.errorbar(eres_teflon[size]['C'], eres_teflon[size]['fwhm'], eres_teflon[size]['fwhm_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
    plt.xlabel('Coverage')
    plt.ylabel('FWHM')
    plt.legend()
    i += 1
plt.title('Kr83m Events, teflon')
plt.show()

# %%
colors = ['r','b','g']
i = 0
for size in eres:
    plt.errorbar(eres_teflon[size]['C'], eres_teflon[size]['eres'], eres_teflon[size]['eres_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
    plt.errorbar(eres[size]['C'], eres[size]['eres'], eres[size]['eres_err'],
                 marker='o', linestyle='--', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.legend()
    i += 1
plt.title('Eres (FWHM) at 41.5 keV')
plt.show()

# %%
colors = ['r','b','g']
i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['eres'], eres[size]['eres_err'],
                 marker='o', linestyle='-', color=colors[i], label=f'{size} mm SiPMs (fast)')
    plt.errorbar(fullsim_eres[size]['C'], fullsim_eres[size]['eres'], eres[size]['eres_err'],
                 marker='o', linestyle='--', color=colors[i], label=f'{size} mm SiPMs (full)')
    plt.xlabel('Coverage')
    plt.legend()
    i += 1
plt.title('Eres (FWHM) at 41.5 keV')
plt.show()

# %%
# 0vbb Events
data0vbb_r400_s2 = {'rcut':400, 'sthresh':2, 'data':{"s1.3mmp7mm_teflon": {"sipm_fwhm_err": 455.62134627358955, "teflon": "teflon", "name": "1.3 mm size, 7 pitch, teflon", "sipm_chi2": 32.41627894961804, "rcut": 400, "sipm_eres_err": 0.0021720062642536946, "sipm_eres": 24.197749373982038, "coverage": 3.3930384230655766, "pitch": 7, "num_sipms": 15268, "sipm_fwhm": 125670.23820798956, "sipm_mean": 519346.8048029004, "sipm_mean_err": 624.2740187232592, "sthresh": 2, "size": 1.3}, "s6mmp15mm": {"sipm_fwhm_err": 1625.2329211251213, "teflon": "no_teflon", "name": "6 mm size, 15 pitch, no_teflon", "sipm_chi2": 26.01019154514069, "rcut": 400, "sipm_eres_err": 0.0012457799883720364, "sipm_eres": 13.601499629860564, "coverage": 15.65986174146311, "pitch": 15, "num_sipms": 3308, "sipm_fwhm": 424422.2482995625, "sipm_mean": 3120407.7480382463, "sipm_mean_err": 2265.5481050230946, "sthresh": 42, "size": 6}, "s3mmp7mm_teflon": {"sipm_fwhm_err": 2603.2723220607036, "teflon": "teflon", "name": "3 mm size, 7 pitch, teflon", "sipm_chi2": 39.95037544787057, "rcut": 400, "sipm_eres_err": 0.0018473892894268309, "sipm_eres": 20.498091032466025, "coverage": 18.06943538910662, "pitch": 7, "num_sipms": 15268, "sipm_fwhm": 705973.5312508349, "sipm_mean": 3444094.0384774096, "sipm_mean_err": 3629.263312148813, "sthresh": 10, "size": 3}, "s1.3mmp15mm_teflon": {"sipm_fwhm_err": 108.78482779001565, "teflon": "teflon", "name": "1.3 mm size, 15 pitch, teflon", "sipm_chi2": 32.701641268327414, "rcut": 400, "sipm_eres_err": 0.0022946390121082834, "sipm_eres": 25.649509647179162, "coverage": 0.735143509529796, "pitch": 15, "num_sipms": 3308, "sipm_fwhm": 30336.485888261668, "sipm_mean": 118273.16118535609, "sipm_mean_err": 151.1515740653474, "sthresh": 2, "size": 1.3}, "s3mmp15mm": {"sipm_fwhm_err": 395.9985597440519, "teflon": "no_teflon", "name": "3 mm size, 15 pitch, no_teflon", "sipm_chi2": 24.766562099456703, "rcut": 400, "sipm_eres_err": 0.0013614620446548834, "sipm_eres": 14.838690376372844, "coverage": 3.9149654353657777, "pitch": 15, "num_sipms": 3308, "sipm_fwhm": 103522.50910989195, "sipm_mean": 697652.599280105, "sipm_mean_err": 545.3364073758495, "sthresh": 10, "size": 3}, "s1.3mmp1.3mm": {"sipm_fwhm_err": 9865.57516996695, "teflon": "no_teflon", "name": "1.3 mm size, 1.3 pitch, no_teflon", "sipm_chi2": 21.159080176539657, "rcut": 400, "sipm_eres_err": 0.00172515719467585, "sipm_eres": 18.8957497961316, "coverage": 98.38322472381753, "pitch": 1.3, "num_sipms": 442705, "sipm_fwhm": 2621604.6513658115, "sipm_mean": 13874044.055677084, "sipm_mean_err": 13394.599629048575, "sthresh": 2, "size": 1.3}, "s1.3mmp15mm": {"sipm_fwhm_err": 68.5965229293797, "teflon": "no_teflon", "name": "1.3 mm size, 15.0 pitch, no_teflon",
"pitch": 7, "num_sipms": 15268, "sipm_fwhm": 48242.83678497499, "sipm_mean": 502386.9397812915, "sipm_mean_err": 356.46834774617764, "sthresh": 2, "size": 1.3}, "s3mmp7mm": {"sipm_fwhm_err": 1574.9357259714802, "teflon": "no_teflon", "name": "3 mm size, 7 pitch, no_teflon", "sipm_chi2": 31.17125117332584, "rcut": 300, "sipm_eres_err": 0.0011059524889363956, "sipm_eres": 8.345439856958974, "coverage": 18.06943538910662, "pitch": 7, "num_sipms": 15268, "sipm_fwhm": 280961.9800686172, "sipm_mean": 3366652.745503075, "sipm_mean_err": 2072.8522291616778, "sthresh": 10, "size": 3}, "s6mmp15mm_teflon": {"sipm_fwhm_err": 2193.4543333270726, "teflon": "teflon", "name": "6 mm size, 15 pitch, teflon", "sipm_chi2": 27.0502808583855, "rcut": 300, "sipm_eres_err": 0.00143715657944856, "sipm_eres": 11.435541074061819, "coverage": 15.65986174146311, "pitch": 15, "num_sipms": 3308, "sipm_fwhm": 414686.1986795812, "sipm_mean": 3626292.765632014, "sipm_mean_err": 2858.68239801233, "sthresh": 42, "size": 6}, "s3mmp15mm_teflon": {"sipm_fwhm_err": 482.0192873317229, "teflon": "teflon", "name": "3 mm size, 15 pitch, teflon", "sipm_chi2": 28.829807266366505, "rcut": 300, "sipm_eres_err": 0.001365422260895178, "sipm_eres": 11.982499609241763, "coverage": 3.9149654353657777, "pitch": 15, "num_sipms": 3308, "sipm_fwhm": 100818.36716620499, "sipm_mean": 841380.099761878, "sipm_mean_err": 680.5063645596146, "sthresh": 10, "size": 3}, "s3mmp3mm": {"sipm_fwhm_err": 8223.255097925008, "teflon": "no_teflon", "name": "3 mm size, 3 pitch, no_teflon", "sipm_chi2": 40.25937148133581, "rcut": 300, "sipm_eres_err": 0.0011104915229144987, "sipm_eres": 8.154891032754957, "coverage": 98.37593314671852, "pitch": 3, "num_sipms": 83124, "sipm_fwhm": 1427363.7948089244, "sipm_mean": 17503162.078754593, "sipm_mean_err": 10894.863352884675, "sthresh": 10, "size": 3}}}

# %%
this_data = data0vbb_r300_s5
cuts = f"R < {this_data['rcut']}, 1mm SiPMs > {this_data['sthresh']}"
this_data = this_data['data']
eres = {1.3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
        3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
        6:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}} 
eres_teflon = {1.3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
               3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
               6:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}} 
for config in this_data:
    size = this_data[config]['size']
    if this_data[config]['teflon']=='no_teflon':
        eres[size]['C'].append(this_data[config]['coverage'])
        eres[size]['eres'].append(this_data[config]['sipm_eres'])
        eres[size]['mean'].append(this_data[config]['sipm_mean'])
        eres[size]['fwhm'].append(this_data[config]['sipm_fwhm'])
        eres[size]['eres_err'].append(this_data[config]['sipm_eres_err'])
        eres[size]['mean_err'].append(this_data[config]['sipm_mean_err'])
        eres[size]['fwhm_err'].append(this_data[config]['sipm_fwhm_err'])
    else:
        eres_teflon[size]['C'].append(this_data[config]['coverage'])
        eres_teflon[size]['eres'].append(this_data[config]['sipm_eres'])
        eres_teflon[size]['mean'].append(this_data[config]['sipm_mean'])
        eres_teflon[size]['fwhm'].append(this_data[config]['sipm_fwhm'])
        eres_teflon[size]['eres_err'].append(this_data[config]['sipm_eres_err'])
        eres_teflon[size]['mean_err'].append(this_data[config]['sipm_mean_err'])
        eres_teflon[size]['fwhm_err'].append(this_data[config]['sipm_fwhm_err'])
        
i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['eres'], eres[size]['eres_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('Eres (FWHM) % at Qbb')
    plt.legend()
    i += 1
plt.title('0vbb Events, no teflon, '+cuts)
plt.show()

i = 0
for size in eres:
    plt.errorbar(eres_teflon[size]['C'], eres_teflon[size]['eres'], eres_teflon[size]['eres_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
    plt.xlabel('Coverage')
    plt.ylabel('Eres (FWHM) % at Qbb')
    plt.legend()
    i += 1
plt.title('0vbb Events, teflon, '+cuts)
plt.show() 

i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['mean'], eres[size]['mean_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('Mean Charge [pes]')
    #plt.ylim(-10000,360000)
    plt.legend()
    i += 1
plt.title('0vbb Events, no teflon, '+cuts)
plt.show()

i = 0
for size in eres:
    plt.errorbar(eres_teflon[size]['C'], eres_teflon[size]['mean'], eres_teflon[size]['mean_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
    plt.xlabel('Coverage')
    plt.ylabel('Mean Charge [pes]')
    plt.legend()
    i += 1
plt.title('Kr83m Events, teflon, '+cuts)
plt.show() 

i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['fwhm'], eres[size]['fwhm_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('FWHM')
    #plt.ylim(-500, 50000)
    plt.legend()
    i += 1
plt.title('0vbb Events, no teflon, '+cuts)
plt.show()

i = 0
for size in eres:
    plt.errorbar(eres_teflon[size]['C'], eres_teflon[size]['fwhm'], eres_teflon[size]['fwhm'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
    plt.xlabel('Coverage')
    plt.ylabel('FWHM')
    plt.legend()
    i += 1
plt.title('0vbb Events, teflon, '+cuts)
plt.show()

# %%
eres[3]['eres_err']
# Out:
# [0.0010986547776518304, 0.0009233548569700257, 0.0011378338757290659]

# %% [markdown]
# # New Sims based on Coverage

# %%
new_sims_old = {"rcut":300, "sthresh":2, "data":{"s1.3mmp2.9mm": {"sipm_fwhm_err": 4.718142086997939, "teflon": "no_teflon", "name": "1.3 mm size, 2.9 pitch, no_teflon", "sipm_chi2": 1.0780579718599008, "rcut": 300, "sipm_eres_err": 0.00032886477355494466, "sipm_eres": 2.681674265943831, "coverage": 19.771760247689368, "pitch": 2.9, "num_sipms": 88969, "sipm_fwhm": 904.7234911112166, "sipm_mean": 33737.26267208646, "sipm_mean_err": 6.413132374598557, "sthresh": 2, "size": 1.3}, "s1.3mmp2.37mm": {"sipm_fwhm_err": 6.661983001242748, "teflon": "no_teflon", "name": "1.3 mm size, 2.37 pitch, no_teflon", "sipm_chi2": 1.300638105276289, "rcut": 300, "sipm_eres_err": 0.0003098390872739671, "sipm_eres": 2.525177723688612, "coverage": 29.601304555431938, "pitch": 2.37, "num_sipms": 133200, "sipm_fwhm": 1276.6807843934434, "sipm_mean": 50558.05666337627, "sipm_mean_err": 9.046855226970806, "sthresh": 2, "size": 1.3}, "s1.3mmp4.11mm": {"sipm_fwhm_err": 2.583517322920112, "te
"teflon": "no_teflon", "name": "1.3 mm size, 1.3 pitch, no_teflon", "sipm_chi2": 0.974662891974422, "rcut": 300, "sipm_eres_err": 0.029661719207251126, "sipm_eres": 2.415748981981068, "coverage": 98.38322472381753, "pitch": 1.3, "num_sipms": 442705, "sipm_fwhm": 4065.8111603168813, "sipm_mean": 168304.37229379095, "sipm_mean_err": 28.756296420371154, "sthresh": 2, "size": 1.3}, "s1.3mmp15mm": {"sipm_fwhm_err": 0.483093644233006, "teflon": "no_teflon", "name": "1.3 mm size, 15.0 pitch, no_teflon", "sipm_chi2": 1.9356641810969595, "rcut": 300, "sipm_eres_err": 0.09058290721997543, "sipm_eres": 7.39941859920401, "coverage": 0.735143509529796, "pitch": 15.0, "num_sipms": 3308, "sipm_fwhm": 93.21588949271565, "sipm_mean": 1259.7731597823554, "sipm_mean_err": 0.6647296333344721, "sthresh": 2, "size": 1.3}, "s1.3mmp7mm": {"sipm_fwhm_err": 1.2201404346443536, "teflon": "no_teflon", "name": "1.3 mm size, 7 pitch, no_teflon", "sipm_chi2": 1.3241244876959317, "rcut": 300, "sipm_eres_err": 0.04962222486227926, "sipm_eres": 4.071637669218686, "coverage": 3.3930384230655766, "pitch": 7, "num_sipms": 15268, "sipm_fwhm": 235.63951738140977, "sipm_mean": 5787.340046557411, "sipm_mean_err": 1.6752265607397885, "sthresh": 2, "size": 1.3}, "s1.3mmp5.82mm": {"sipm_fwhm_err": 1.5371652578770443, "teflon": "no_teflon", "name": "1.3 mm size, 5.82 pitch, no_teflon", "sipm_chi2": 1.2726145452799367, "rcut": 300, "sipm_eres_err": 0.04409849627435124, "sipm_eres": 3.5680793912400723, "coverage": 4.907771845361553, "pitch": 5.82, "num_sipms": 22084, "sipm_fwhm": 292.6198291049369, "sipm_mean": 8201.045913477783, "sipm_mean_err": 2.0779517938652377, "sthresh": 2, "size": 1.3}, "s1.3mmp1.84mm": {"sipm_fwhm_err": 10.868898750252855, "teflon": "no_teflon", "name": "1.3 mm size, 1.84 pitch, no_teflon", "sipm_chi2": 0.9469397197861661, "rcut": 300, "sipm_eres_err": 0.030451116891161888, "sipm_eres": 2.480268654218689, "coverage": 49.11883137660919, "pitch": 1.84, "num_sipms": 221025, "sipm_fwhm": 2081.582309024696, "sipm_mean": 83925.67899788325, "sipm_mean_err": 14.714155569880527, "sthresh": 2, "size": 1.3}}}

# %%
this_data = new_sims
cuts = f"R < {this_data['rcut']}, 1mm SiPMs > {this_data['sthresh']}"
this_data = this_data['data']
eres = {1.3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}} 
#        3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
#        6:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}} 
#eres_teflon = {1.3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
#               3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
#               6:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}} 
for config in this_data:
    size = this_data[config]['size']
    if this_data[config]['teflon']=='no_teflon':
        eres[size]['C'].append(this_data[config]['coverage'])
        eres[size]['eres'].append(this_data[config]['sipm_eres'])
        eres[size]['mean'].append(this_data[config]['sipm_mean'])
        eres[size]['fwhm'].append(this_data[config]['sipm_fwhm'])
        eres[size]['eres_err'].append(this_data[config]['sipm_eres_err'])
        eres[size]['mean_err'].append(this_data[config]['sipm_mean_err'])
        eres[size]['fwhm_err'].append(this_data[config]['sipm_fwhm_err'])
#    else:
#        eres_teflon[size]['C'].append(this_data[config]['coverage'])
#        eres_teflon[size]['eres'].append(this_data[config]['sipm_eres'])
#        eres_teflon[size]['mean'].append(this_data[config]['sipm_mean'])
#        eres_teflon[size]['fwhm'].append(this_data[config]['sipm_fwhm'])
#        eres_teflon[size]['eres_err'].append(this_data[config]['sipm_eres_err'])
#        eres_teflon[size]['mean_err'].append(this_data[config]['sipm_mean_err'])
#        eres_teflon[size]['fwhm_err'].append(this_data[config]['sipm_fwhm_err'])

for size in eres.keys():
    sorted_ind = np.array(eres[size]['C']).argsort()
    for key in eres[size].keys():
        eres[size][key] = np.array(eres[size][key])[sorted_ind[::]]

colors = ['r','b','g']
i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['eres'], eres[size]['eres_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('Eres (FWHM) % at 41.5 keV')
    plt.legend()
    i += 1
plt.title('Kr83m Events, no teflon, '+cuts)
plt.show()

i = 0
#for size in eres:
#    plt.errorbar(eres_teflon[size]['C'], eres_teflon[size]['eres'], eres_teflon[size]['eres_err'],
#                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
#    plt.xlabel('Coverage')
#    plt.ylabel('Eres (FWHM) % at 41.5 keV')
#    plt.legend()
#    i += 1
#plt.title('Kr83m Events, teflon, '+cuts)
#plt.show() 

i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['mean'], eres[size]['mean_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('Mean Charge [pes]')
    #plt.ylim(-10000,360000)
    plt.legend()
    i += 1
plt.title('Kr83m Events, no teflon, '+cuts)
plt.show()

i = 0
#for size in eres:
#    plt.errorbar(eres_teflon[size]['C'], eres_teflon[size]['mean'], eres_teflon[size]['mean_err'],
#                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
#    plt.xlabel('Coverage')
#    plt.ylabel('Mean Charge [pes]')
#    plt.legend()
#    i += 1
#plt.title('Kr83m Events, teflon, '+cuts)
#plt.show() 

i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['fwhm'], eres[size]['fwhm_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('FWHM')
    #plt.ylim(-500, 50000)
    plt.legend()
    i += 1
plt.title('Kr83m Events, no teflon, '+cuts)
plt.show()

#i = 0
#for size in eres:
#    plt.errorbar(eres_teflon[size]['C'], eres_teflon[size]['fwhm'], eres_teflon[size]['fwhm'],
#                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs with teflon")
#    plt.xlabel('Coverage')
#    plt.ylabel('FWHM')
#    plt.legend()
#    i += 1
#plt.title('Kr83m Events, teflon, '+cuts)
#plt.show()

# %%
all_sims = {'rcut':300, 'sthresh':2, 'data':{"s1.3mmp2.37mm": {"sipm_fwhm_err": 6.661983001242748, "teflon": "no_teflon", "name": "1.3 mm size, 2.37 pitch, no_teflon", "sipm_chi2": 1.300638105276289, "rcut": 300, "sipm_eres_err": 0.030983908727396706, "sipm_eres": 2.525177723688612, "coverage": 29.601304555431938, "pitch": 2.37, "num_sipms": 133200, "sipm_fwhm": 1276.6807843934434, "sipm_mean": 50558.05666337627, "sip
on", "sipm_chi2": 1.0752624838183389, "rcut": 300, "sipm_eres_err": 0.029268914299706888, "sipm_eres": 2.3830483493512316, "coverage": 39.33427787479353, "pitch": 9.49, "num_sipms": 8309, "sipm_fwhm": 2391.0980859666574, "sipm_mean": 100337.79157764956, "sipm_mean_err": 16.98415334255767, "sthresh": 42, "size": 6}, "s3mmp9.49mm": {"sipm_fwhm_err": 3.3689719394256663, "teflon": "no_teflon", "name": "3 mm size, 9.49 pitch, no_teflon", "sipm_chi2": 1.0586680723958897, "rcut": 300, "sipm_eres_err": 0.035875473981231316, "sipm_eres": 2.8332203121225716, "coverage": 9.833569468698382, "pitch": 9.49, "num_sipms": 8309, "sipm_fwhm": 625.6797792431482, "sipm_mean": 22083.696653099523, "sipm_mean_err": 4.451909250995701, "sthresh": 10, "size": 3}, "s1.3mmp1.3mm": {"sipm_fwhm_err": 21.232028520073094, "teflon": "no_teflon", "name": "1.3 mm size, 1.3 pitch, no_teflon", "sipm_chi2": 0.9746628919750271, "rcut": 300, "sipm_eres_err": 0.029661716827185186, "sipm_eres": 2.415748955929122, "coverage": 98.38322472381753, "pitch": 1.3, "num_sipms": 442705, "sipm_fwhm": 4065.8111161619704, "sipm_mean": 168304.3722810269, "sipm_mean_err": 28.756297673608643, "sthresh": 2, "size": 1.3}, "s3mmp4.74mm": {"sipm_fwhm_err": 10.877030773071537, "teflon": "no_teflon", "name": "3 mm size, 4.74 pitch, no_teflon", "sipm_chi2": 1.2658060007873375, "rcut": 300, "sipm_eres_err": 0.02887685314190416, "sipm_eres": 2.4127108581757395, "coverage": 39.410020857823575, "pitch": 4.74, "num_sipms": 33300, "sipm_fwhm": 2136.8889717381076, "sipm_mean": 88567.96762434344, "sipm_mean_err": 15.249695496673352, "sthresh": 10, "size": 3}, "s3mmp5.48mm": {"sipm_fwhm_err": 8.502561321983512, "teflon": "no_teflon", "name": "3 mm size, 5.48 pitch, no_teflon", "sipm_chi2": 0.7326789990686129, "rcut": 300, "sipm_eres_err": 0.030171724684864627, "sipm_eres": 2.4727509838903816, "coverage": 29.498341437875457, "pitch": 5.48, "num_sipms": 24925, "sipm_fwhm": 1638.493279368314, "sipm_mean": 66261.96046600984, "sipm_mean_err": 11.595045331105009, "sthresh": 10, "size": 3}, "s3mmp4.24mm": {"sipm_fwhm_err": 13.567931088789123, "teflon": "no_teflon", "name": "3 mm size, 4.24 pitch, no_teflon", "sipm_chi2": 0.9095193332462931, "rcut": 300, "sipm_eres_err": 0.02881914377808791, "sipm_eres": 2.3790472406260537, "coverage": 49.224654580764444, "pitch": 4.24, "num_sipms": 41593, "sipm_fwhm": 2633.515835846115, "sipm_mean": 110696.23969102425, "sipm_mean_err": 18.664440403473964, "sthresh": 10, "size": 3}, "s1.3mmp4.11mm": {"sipm_fwhm_err": 2.583517340991673, "teflon": "no_teflon", "name": "1.3 mm size, 4.11 pitch, no_teflon", "sipm_chi2": 1.5469900888972559, "rcut": 300, "sipm_eres_err": 0.037124967648654666, "sipm_eres": 
893177444, "sthresh": 42, "size": 6}, "s6mmp6mm": {"sipm_fwhm_err": 29.603333923592306, "teflon": "no_teflon", "name": "6 mm size, 6 pitch, no_teflon", "sipm_chi2": 0.6603967608219611, "rcut": 300, "sipm_eres_err": 0.027708345557494053, "sipm_eres": 2.256790050939427, "coverage": 98.39486889247604, "pitch": 6, "num_sipms": 20785, "sipm_fwhm": 5668.8257362580725, "sipm_mean": 251189.7699078533, "sipm_mean_err": 40.22074610816176, "sthresh": 42, "size": 6}, "s3mmp15mm": {"sipm_fwhm_err": 1.6412796762768058, "teflon": "no_teflon", "name": "3 mm size, 15 pitch, no_teflon", "sipm_chi2": 1.190696906706595, "rcut": 300, "sipm_eres_err": 0.043665956236910705, "sipm_eres": 3.5181484846856117, "coverage": 3.9149654353657777, "pitch": 15, "num_sipms": 3308, "sipm_fwhm": 311.106643796191, "sipm_mean": 8842.908284014398, "sipm_mean_err": 2.2120025219118076, "sthresh": 10, "size": 3}, "s1.3mmp1.84mm": {"sipm_fwhm_err": 10.868898720422985, "teflon": "no_teflon", "name": "1.3 mm size, 1.84 pitch, no_teflon", "sipm_chi2": 0.9469397197861658, "rcut": 300, "sipm_eres_err": 0.030451116807687417, "sipm_eres": 2.4802686541977894, "coverage": 49.11883137660919, "pitch": 1.84, "num_sipms": 221025, "sipm_fwhm": 2081.582309007183, "sipm_mean": 83925.67899788436, "sipm_mean_err": 14.714155572321197, "sthresh": 2, "size": 1.3}}}
full_sims_kr = [3.48, 3.09, 2.95]
full_sims_kr_err = [0.046, 0.0397,0.0384]
full_sims_0vbb = [0.47, 0.45, 0.46]
full_sims_0vbb_err = [0.008, 0.0085, 0.006]
full_names = ['s1.3mmp3.5', 's1.3mmp2.4mm', 's3mmp5.5mm']
full_cov = [13.567, 28.86, 29.28]

# %%
this_data = all_sims
cuts = f"R < {this_data['rcut']}, 1mm SiPMs > {this_data['sthresh']}"
eres = {1.3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
        3:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}, 
        6:{'C':[],'eres':[], 'mean':[], 'fwhm':[],'eres_err':[], 'mean_err':[], 'fwhm_err':[]}} 
this_data = this_data['data']
for config in this_data:
    size = this_data[config]['size']
    if this_data[config]['teflon']=='no_teflon':
        eres[size]['C'].append(this_data[config]['coverage'])
        eres[size]['eres'].append(this_data[config]['sipm_eres'])
        eres[size]['mean'].append(this_data[config]['sipm_mean'])
        eres[size]['fwhm'].append(this_data[config]['sipm_fwhm'])
        eres[size]['eres_err'].append(this_data[config]['sipm_eres_err'])
        eres[size]['mean_err'].append(this_data[config]['sipm_mean_err'])
        eres[size]['fwhm_err'].append(this_data[config]['sipm_fwhm_err'])
        
for size in eres.keys():
    sorted_ind = np.array(eres[size]['C']).argsort()
    for key in eres[size].keys():
        eres[size][key] = np.array(eres[size][key])[sorted_ind[::]]

colors = ['r','b','g']
i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['eres'], eres[size]['eres_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('Eres (FWHM) % at 41.5 keV')
    plt.legend()
    i += 1
plt.title('Kr83m Events, no teflon, '+cuts)
plt.show()

i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['mean'], eres[size]['mean_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('Mean Charge [pes]')
    #plt.ylim(-10000,360000)
    plt.legend()
    i += 1
plt.title('Kr83m Events, no teflon, '+cuts)
plt.show()

i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['fwhm'], eres[size]['fwhm_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    plt.xlabel('Coverage')
    plt.ylabel('FWHM')
    #plt.ylim(-500, 50000)
    plt.legend()
    i += 1
plt.title('Kr83m Events, no teflon, '+cuts)
plt.show()

# %%
colors = ['r','b','g']
i = 0
for size in eres:
    plt.errorbar(eres[size]['C'], eres[size]['eres'], eres[size]['eres_err'],
                 marker='o', linestyle='-', color=colors[i], label=f"{size}mm SiPMs")
    i += 1
plt.errorbar(full_cov, full_sims_kr, full_sims_kr_err, marker='o', color='m', label='Full simulations')
plt.title('Kr83m Events, no teflon, '+cuts)
plt.legend()
plt.xlabel('Coverage')
plt.ylabel('Eres (FWHM) % at 41.5 keV')
plt.show()

# %%
data = {'s1.3mmp2.4mm': {'Eu': [0.006511480241366076, 0.006513959888380765, 0.006433693907057242, 0.00634411449981459, 0.006192495731712602, 0.005858294158167676], 'Eres': [0.4783315026919272, 0.4769363504203005, 0.47745902190294187, 0.472768494440247, 0.44507044059325385, 0.3943682455499821], 'sthresh': [0, 1, 2, 3, 4, 5]}, 's1.3mmp3.5mm': {'Eu': [0.007097468860985913, 0.007088238046198201, 0.006963866466126238, 0.006840601779152719, 0.006687799912771602, 0.006003261133489971], 'Eres': [0.5041429372215083, 0.5038493852923818, 0.5001265693658679, 0.4907399159462121, 0.4671842020945047, 0.4328099540816189], 'sthresh': [0, 1, 2, 3, 4, 5]}, 's3mmp5.5mm': {'Eu': [0.006548866463573539, 0.006548867850022878, 0.006769238472030519, 0.006769102566861888, 0.006770800898520719, 0.006753459649074852], 'Eres': [0.4810383819958573, 0.4810384901960162, 0.48652166762161225, 0.48644925196792116, 0.4864705150023724, 0.4864958952582418], 'sthresh': [0, 1, 2, 3, 4, 5]}}
for config in ['s1.3mmp2.4mm']:
    plt.errorbar(data[config]['sthresh'], data[config]['Eres'], data[config]['Eu'], marker='o', label=config)
plt.xlabel('SiPM Threshold')
plt.ylabel('Eres FWHM (%)')
plt.legend()
plt.show()

# %%
data = {'s1.3mmp2.4mm': {'Eu': [0.006511480241366076, 0.020529743298879456, 0.006513959888380765, 0.006433693907057242, 0.00634411449981459, 0.006192495731712602, 0.005858294158167676, 0.004771753885208924, 0.00595520118583492, 0.009399893655572972, 0.013570791479668687], 'Eres': [0.4783315026919272, 1.2834857900170726, 0.4769363504203005, 0.47745902190294187, 0.472768494440247, 0.44507044059325385, 0.3943682455499821, 0.33580028482229646, 0.41458904030040133, 0.6845772827395886, 1.001442739547343], 'sthresh': [0, 10, 1, 2, 3, 4, 5, 6, 7, 8, 